# %% [markdown]
# # CS 508 Module Eight: Graph Traversal Model
#
# This notebook models Graph 1 as an undirected weighted graph and Graph 2 as a directed weighted graph. It produces adjacency lists, weighted adjacency matrices, BFS and DFS orders, global shortest/longest simple paths, and shortest paths from vertex 1 using Dijkstra and Bellman–Ford.
#
# **Interpretation rule:** `INF` means no direct edge. Neighbor ties are processed in ascending vertex order. "Longest" means longest *simple* path, so no vertex is repeated.

# %%
# Import the tested implementation stored beside this notebook.
from pathlib import Path
import sys

notebook_dir = Path.cwd()
if (notebook_dir / "cs508_graph_model.py").exists():
    sys.path.insert(0, str(notebook_dir))
else:
    raise FileNotFoundError("Keep this notebook and cs508_graph_model.py in the same folder.")

from cs508_graph_model import *

# %% [markdown]
# ## Graph 1 Results

# %%
print(report(GRAPH_1))

# %% [markdown]
# ## Graph 2 Results

# %%
print(report(GRAPH_2))

# %% [markdown]
# ## Save Graph Diagrams and Matrix Heatmaps
#
# The following cell creates four PNG files in `graph_outputs`. Matplotlib is optional; the calculations above use only Python's standard library.

# %%
output_dir = notebook_dir / "graph_outputs"
for graph in (GRAPH_1, GRAPH_2):
    save_figures(graph, output_dir)
print(f"Figures saved to: {output_dir.resolve()}")

# %% [markdown]
# ## Results Used in My Journal
#
# I copied the console evidence generated above into my paper. The output shows that both shortest-path algorithms agree. It also records each assumption needed to reproduce my BFS, DFS, matrix, and simple-path results.
